# %% [markdown]
# <a href="https://colab.research.google.com/github/joosunlee/HF_Project/blob/main/01_HF_Transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.53.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.33.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.7.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.7.14)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 49.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 41.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 23.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import torch
from transformers import pipeline
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification

# %%
import pandas as pd
df = pd.read_csv('Dropbox.csv')

# %%
df
# Out:
#                                   reviewId  \
# 0     401cf934-916f-4af9-88ee-4a93ee52aab0
# 1     b6a3a141-0556-4f33-8ea3-181c29c0dd99
# 2     784c44e5-f84b-4e9e-950a-446e030a53a1
# 3     8605953c-71c9-4eea-b3f0-1bbac1889b60
# 4     7f8a6e07-7176-4cee-a268-2e09eb783e6a
# ...                                    ...
# 9995  ddd5c2fa-43b7-4eb0-859f-584cde1eabc9
# 9996  42ea8493-5776-4615-b2eb-666e8dfaa02d
# 9997  9e2cd1e3-c7d0-424f-acef-af87bf3c9c86
# 9998  2fd02992-4e3b-4d0d-a653-4036771c8b12
# 9999  69e8bb8e-f8d4-407c-9eb7-811e2ef1857d
#
#                                                 content  score
# 0     not able to view photos or files, but want me ...      1
# 1     The app is good, but their free plan with 2GB ...      4
# 2                                           I Love it 🥰      5
# 3     whenever I try to download a file on an Androi...      2
# 4     Downloads will fail randomly for no reason wha...      1
# ...                                                 ...    ...
# 9995                                               Good      5
# 9996                                 connection problem      3
# 9997                                     Dream in color      5
# 9998      Vital. Still need to get into my account tho.      5
# 9999                                      User Friendly      4
#
# [10000 rows x 3 columns]

# %%
df = df.sample(200)

# %%
df
# Out:
#                                   reviewId  \
# 2809  97122f45-ef2e-4002-8e08-2c4e5b4c18f8
# 341   9fb5b5bd-0038-44c4-b7b6-7f01adc7dfef
# 3417  68c729df-69a7-408c-87c2-a21a17f7225e
# 1140  841383d4-410e-4be1-abb0-02693d0fe1df
# 7466  8d16fc7f-44d3-4ba2-add5-ffa76ff51949
# ...                                    ...
# 4899  6cc45a6d-799b-4742-b9f5-a7aad8cc92bb
# 6559  892e89c6-6e33-46e2-9669-69547dbe9b1c
# 6510  6e0d595a-c846-4dc1-8b6d-a08fa346788e
# 2238  f5d9e2a8-8be6-4498-9b42-3717cc3f56ab
# 8365  195e965f-7ac3-4639-acf5-d6dbb3e3e9c8
#
#                                                 content  score
# 2809  Fraudulent company... beware! Dropbox took mon...      1
# 341                          I love drop box. awesome!!      5
# 3417  Can I please use the app for my pictures. So I...      5
# 1140                                        easy to use      5
# 7466  is good but I don't like because I can't not d...      2
# ...                                                 ...    ...
# 4899                 This destination storage thank you      5
# 6559  Fine for years until recently. All of a sudden...      3
# 6510          Can't find the delete subscription option      1
# 2238                                               good      4
# 8365    Trying to cancel subscription is impossible....      1
#
# [200 rows x 3 columns]

# %%
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")
model = DistilBertForSequenceClassification.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")

nlp = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)

texts = list(df.content.values)
results = nlp(texts)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
for text, result, score in zip(texts, results, df.score.values):
  print('Text:', text)
  print('Result:', result)
  print('Score:', score)
# Out:
# Text: Fraudulent company... beware! Dropbox took money out of my account . I tried canceling my subscription the next day to no avail. There isn't a live person to talk with. This company is awful!
# Result: {'label': 'NEGATIVE', 'score': 0.9997507929801941}
# Score: 1
# Text: I love drop box. awesome!!
# Result: {'label': 'POSITIVE', 'score': 0.9998733997344971}
# Score: 5
# Text: Can I please use the app for my pictures. So I can delete unwanted websites from my device ?
# Result: {'label': 'NEGATIVE', 'score': 0.9995306730270386}
# Score: 5
# Text: easy to use
# Result: {'label': 'POSITIVE', 'score': 0.9988542795181274}
# Score: 5
# Text: is good but I don't like because I can't not download rodeo dc2
# Result: {'label': 'POSITIVE', 'score': 0.9007875323295593}
# Score: 2
# Text: Это ДропПёс Я не могу зайти в аккаунт ни с браузера ни с приложения минут 15
# Result: {'label': 'NEGATIVE', 'score': 0.5613244771957397}
# Score: 1
# Text: Unable to copy files to SD disk
# Result: {'label': 'NEGATIVE', 'score': 0.9971542358398438}
# Score: 1
# Text: Nice appa
# Result: {'label': 'POSITIVE', 'score': 0.9998340606689453}
# Score: 5
# Text: great way to store and share documents and pictures
# Result: {'label': 'POSITIVE', 'score': 0.9997676014900208}
# Score: 5
# Text: I'm just learning about it. I'm don't get out and need away to send someone something. Thank You for the feedback.
# Result: {'label': 'POSITIVE', 'score': 0.9996206760406494}
# Score: 5
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: My photos
# Result: {'label': 'POSITIVE', 'score': 0.9026333093643188}
# Score: 4
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: easy tnstallment.
# Result: {'label': 'NEGATIVE', 'score': 0.9873048663139343}
# Score: 5
# Text: I HATE this app. I have a photography business and it now takes me almost an hour to upload 30 photos. And it frequently freezes up altogether. It's like I need to buy a 2nd computer just for uploading photos to garbage dropbox because it ties up the computer for so long.I have the most expensive subscription and the fastest internet available. It makes my normal work day much more difficult. The only part of my work day I don't like is dealing with dropbox.
# Result: {'label': 'NEGATIVE', 'score': 0.9993659853935242}
# Score: 1
# Text: Ok
# Result: {'label': 'POSITIVE', 'score': 0.9997851252555847}
# Score: 5
# Text: It's impossible to cancel the account!!!
# Result: {'label': 'POSITIVE', 'score': 0.9331544637680054}
# Score: 1
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: Excellent app
# Result: {'label': 'POSITIVE', 'score': 0.9998356103897095}
# Score: 5
# Text: absolutely terrible experience..i use this to save space on my computer and the syncing features is useless or not customer friendly. i accidentally deleted a lot of important folders and it was devastating.
# Result: {'label': 'NEGATIVE', 'score': 0.9997637867927551}
# Score: 1
# Text: great
# Result: {'label': 'POSITIVE', 'score': 0.9998630285263062}
# Score: 5
# Text: 🟦🟦🟦🟦🟦🟪🟪🟪🟪🟪⬜⬜⬜⬜⬜⬛⬛⬛⬛⬛⬜⬜⬜⬜⬜
# Result: {'label': 'NEGATIVE', 'score': 0.697055995464325}
# Score: 3
# Text: Files lost. Recovery using 8 email logons, not able to merge MSN, Hotmail, Gmail, Yahoo, Outlook, in Dropbox subscriptions in email accounts to combine storage in Dropbox cloud family storage. Older users are not given intuitive setup, how to's, recover, sync &backup, Dropbox apps to locate, convert, identify duplicate files, upload stored data apps ie: G Drive, MS OneDrive, G Photos, Amazon Photos, G One+ apps data upload to Dropbox Cloud as the main source for all storage apps& merge platforms
# Result: {'label': 'NEGATIVE', 'score': 0.9989087581634521}
# Score: 1
# Text: Always have access and backup to your important documents and files from anywhere, with ease and without worry.
# Result: {'label': 'POSITIVE', 'score': 0.9992411136627197}
# Score: 5
# Text: ok
# Result: {'label': 'POSITIVE', 'score': 0.9997851252555847}
# Score: 3
# Text: 💫
# Result: {'label': 'NEGATIVE', 'score': 0.697055995464325}
# Score: 5
# Text: It is quite wonderful!. I need to experience with it sll themore.
# Result: {'label': 'POSITIVE', 'score': 0.9997678399085999}
# Score: 1
# Text: constantly getting error messages
# Result: {'label': 'NEGATIVE', 'score': 0.9988277554512024}
# Score: 3
# Text: I have ten years use the Dropbox app But now it doesn't show me the folders, it says to pay and now I lost all my data
# Result: {'label': 'NEGATIVE', 'score': 0.9996966123580933}
# Score: 2
# Text: Finding live support sucks...
# Result: {'label': 'NEGATIVE', 'score': 0.9996379613876343}
# Score: 1
# Text: They are garbage. I recommend else were. For free too. Google is free thanks!
# Result: {'label': 'NEGATIVE', 'score': 0.9926965236663818}
# Score: 1
# Text: great app
# Result: {'label': 'POSITIVE', 'score': 0.999821126461029}
# Score: 5
# Text: Bait & switch for no good reason. In order to view a PDF file Dropbox said I had to install Dropbox for Android on my phone...then when I did Dropbox for Android said I had to unlink 6 devices from my Dropbox account. I already have Adobe PDF Reader for Android...why can't I just view the file? It seems like Dropbox has decided to hold my data hostage and now wants me to pay for a monthly plan.
# Result: {'label': 'NEGATIVE', 'score': 0.9996552467346191}
# Score: 1
# Text: I signed up for the paid version it want even log on..... I just get a black screen...
# Result: {'label': 'NEGATIVE', 'score': 0.998925507068634}
# Score: 1
# Text: Helpful keeping files available when I need them
# Result: {'label': 'POSITIVE', 'score': 0.9978196620941162}
# Score: 4
# Text: Ethio
# Result: {'label': 'POSITIVE', 'score': 0.9912207722663879}
# Score: 1
# Text: ad free, easy to use, easy to drop files and share files to other. this is super nice🫡
# Result: {'label': 'NEGATIVE', 'score': 0.9246236085891724}
# Score: 5
# Text: Works for me!
# Result: {'label': 'POSITIVE', 'score': 0.9998006224632263}
# Score: 5
# Text: I m getting this error Dropbox’s request does not comply with Google’s ”Use secure browsers” policy. If this app has a website, you can open a web browser and try signing in from there. If you are attempting to access a wireless network, please follow these instructions. You can also contact the developer to let them know their app must comply with Google’s ”Use secure browsers” policy. Learn more about this error If you are a developer of Dropbox, see error details. Error 403: disallowe
# Result: {'label': 'NEGATIVE', 'score': 0.9993552565574646}
# Score: 4
# Text: Impossible to cancel subscription. If you get it you will be paying for it the rest of your life.
# Result: {'label': 'NEGATIVE', 'score': 0.9552210569381714}
# Score: 1
# Text: had high hopes, after a couple of months moving all of my pictures, videos, screenshots, documents & other irreplaceable items, I'm only giving a 3 star rate. Trying to transfer everything from Samsung Gallery, inevitably get error that says upload failed. It's frequent & frustrating & lose track of Transfers.Trying to move everything I have from Google & Samsung. However, uploads continue to fail, resulting in wasted time & energy. Gallery is done in August, I'm terrified I'll lose everything.
# Result: {'label': 'NEGATIVE', 'score': 0.9997637867927551}
# Score: 3
# Text: Cannot cancel subscription. Happy to take my money but no information is easy when u want to cancel.
# Result: {'label': 'NEGATIVE', 'score': 0.9942952990531921}
# Score: 1
# Text: I can't even cancel my subscriptions! Your directions suck. I am extremely unhappy with the functionality of Drop Box
# Result: {'label': 'NEGATIVE', 'score': 0.9995251893997192}
# Score: 1
# Text: My previous review was in error. I sincerely apologize. I was confused. I mistook Box for Dropbox. I have adjusted my stars to 4 out of 5 instead of 1. It may be higher, except for my rather limited use of Dropbox to view a shared folder.
# Result: {'label': 'NEGATIVE', 'score': 0.9973688125610352}
# Score: 4
# Text: 👍
# Result: {'label': 'NEGATIVE', 'score': 0.697055995464325}
# Score: 5
# Text: wouldn't use anything else... grateful for many years of good service
# Result: {'label': 'NEGATIVE', 'score': 0.9060345888137817}
# Score: 5
# Text: Bug** can't open files*fixed now
# Result: {'label': 'NEGATIVE', 'score': 0.9996601343154907}
# Score: 4
# Text: great service
# Result: {'label': 'POSITIVE', 'score': 0.9998434782028198}
# Score: 5
# Text: 😄
# Result: {'label': 'NEGATIVE', 'score': 0.697055995464325}
# Score: 5
# Text: What happen to dropbox...extensionless file can't be previewed
# Result: {'label': 'NEGATIVE', 'score': 0.9986734390258789}
# Score: 1
# Text: Drop vin j ay ship up shape shift in order for a number of different types of my partners to make the decision to go through the same situation with a group of people that we have a question about the one who has the right outside his own children to death youtube and to make the most important person to be the person to love you have to be with you
# Result: {'label': 'NEGATIVE', 'score': 0.5317481756210327}
# Score: 4
# Text: I went to hospital and forgot to stop before the payment came out and I'm having a hard time getting a refund! Can someone help me?
# Result: {'label': 'NEGATIVE', 'score': 0.9996681213378906}
# Score: 1
# Text: This app is very good, i like how it integrates with the mobile version of Microsoft suite.
# Result: {'label': 'POSITIVE', 'score': 0.9998488426208496}
# Score: 4
# Text: Was quite good previously. Now seems to be so slow and sluggish
# Result: {'label': 'NEGATIVE', 'score': 0.9970496892929077}
# Score: 3
# Text: It's useless. And cannot cancel. Extremely frustrating
# Result: {'label': 'NEGATIVE', 'score': 0.9900802969932556}
# Score: 1
# Text: Very good review for file stoe or sharing
# Result: {'label': 'POSITIVE', 'score': 0.9993657469749451}
# Score: 5
# Text: Excellent App.
# Result: {'label': 'POSITIVE', 'score': 0.9998461008071899}
# Score: 5
# Text: Been using dropbox until yesterday 22 Aug 24, whereby the image thumbnail link when sending via whatsapp can be seen, now it just a blank image with my url link. Hopefully this can be fixed, other thumbnail image links in whatsapp eg: like YouTube, news link, works fine. Worst part, I cannot talk to everyone about my issue. Today, 24 Aug 24, this problem has resolved, hope it stays that way...changed my rating.
# Result: {'label': 'NEGATIVE', 'score': 0.9979187846183777}
# Score: 5
# Text: reliable and easy to use
# Result: {'label': 'POSITIVE', 'score': 0.999850869178772}
# Score: 5
# Text: it's great but shrinking my file quality in some cases... and I'm looking into if I can adjust that somehow. I want to preserve my quality 😩... other than that phenomenal
# Result: {'label': 'NEGATIVE', 'score': 0.9965053796768188}
# Score: 4
# Text: Great 👍🏾 App!!!!!
# Result: {'label': 'POSITIVE', 'score': 0.9995450377464294}
# Score: 5
# Text: best thing they ever made
# Result: {'label': 'POSITIVE', 'score': 0.9997487664222717}
# Score: 5
# Text: Good to save personal documents in large number
# Result: {'label': 'POSITIVE', 'score': 0.999438464641571}
# Score: 5
# Text: App just crashes, can't even log in. Terrible release.
# Result: {'label': 'NEGATIVE', 'score': 0.9997203946113586}
# Score: 1
# Text: You can't upload document or files. Keeps showing uploading unending. What a waste of time and storage space. Not working
# Result: {'label': 'NEGATIVE', 'score': 0.9998188614845276}
# Score: 1
# Text: Excellent
# Result: {'label': 'POSITIVE', 'score': 0.9998434782028198}
# Score: 5
# Text: My files
# Result: {'label': 'NEGATIVE', 'score': 0.8842595815658569}
# Score: 5
# Text: Very cool and interesting app thank you for this.
# Result: {'label': 'POSITIVE', 'score': 0.9998714923858643}
# Score: 5
# Text: I really like it! I can save my videos and photos on here and then delete them from my phone saved in my photo app that way I can have more storage on my phone to update apps and install apps and such!! It has a 2gb limit...which is fine..cause I can use multiple emails. So far I haven't experienced any issues..thankfully. I can go back and visit my vids...I'm hoping it doesn't like not play or erase or something..since I do delete the vids from my samsung photo app.
# Result: {'label': 'POSITIVE', 'score': 0.930888831615448}
# Score: 5
# Text: خوب
# Result: {'label': 'POSITIVE', 'score': 0.7668716311454773}
# Score: 5
# Text: The greatest storage app ever. I've had this since senior year in high school and that was 2013. I've kept up with every picture since then thanks to Dropbox
# Result: {'label': 'POSITIVE', 'score': 0.999626636505127}
# Score: 5
# Text: best for storage
# Result: {'label': 'POSITIVE', 'score': 0.9564679265022278}
# Score: 5
# Text: 9/10/24 Dropbox is HUNG on my computer. Not my issue. A BETA version of the app UPDATED AUTOMATICALLY, version 208.4.5824 and caused the app to hang on "waiting to connect" which NEVER resolved in 3 days. Not my firewall. I uninstalled and TRIED to rollback to version, 203.4.4857 because another BETA version, 207.3.5702 did the SAME error a week before when it AUTO UPDATED then and REINSTALLING to the 203.4.4857 worked back then. The APP connected and syncbut the Beta update applied and it HUNG
# Result: {'label': 'NEGATIVE', 'score': 0.9994762539863586}
# Score: 1
# Text: Not worth the huge subscription fee, and it's very difficult to opt out. Serious buyer's remorse here.
# Result: {'label': 'NEGATIVE', 'score': 0.9988940358161926}
# Score: 1
# Text: Very good app
# Result: {'label': 'POSITIVE', 'score': 0.9998675584793091}
# Score: 5
# Text: Used to be able to open text files and PDFs through Dropbox. Now when I try to open a file in a DropBox folder, it won't open - says I have to upload to Google Docs to open. May be a problem with my Samsung phone I guess, but I pay a lot for DropBox and would be good if the DropBox App could ensure that its simple doc viewer would work consistently.
# Result: {'label': 'NEGATIVE', 'score': 0.9953475594520569}
# Score: 4
# Text: Best
# Result: {'label': 'POSITIVE', 'score': 0.9997941851615906}
# Score: 5
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: exceptional
# Result: {'label': 'POSITIVE', 'score': 0.9998514652252197}
# Score: 5
# Text: It's user friendly and practical. I've been using this app in every transactions.
# Result: {'label': 'POSITIVE', 'score': 0.9961463212966919}
# Score: 5
# Text: popups anoying
# Result: {'label': 'NEGATIVE', 'score': 0.9754688739776611}
# Score: 3
# Text: thanks so good
# Result: {'label': 'POSITIVE', 'score': 0.999833345413208}
# Score: 5
# Text: Fake
# Result: {'label': 'NEGATIVE', 'score': 0.9996473789215088}
# Score: 1
# Text: Good job
# Result: {'label': 'POSITIVE', 'score': 0.999835729598999}
# Score: 5
# Text: Not secure by password
# Result: {'label': 'NEGATIVE', 'score': 0.9997970461845398}
# Score: 1
# Text: great app
# Result: {'label': 'POSITIVE', 'score': 0.999821126461029}
# Score: 5
# Text: These turds deleted al my info and said my account is no longer active and WILL NOT answer any emails. Stay far far far away from this garbage service. If you look on reddit it is a very common complaint. They do not care! But, they will still try to bill you. There is a class action being formed against them now so look for it. Update: your garbage solution didn't fix your garbage service. GFY
# Result: {'label': 'NEGATIVE', 'score': 0.999617338180542}
# Score: 1
# Text: 🇮🇳 This is the best application. I have been using it for 15 years.
# Result: {'label': 'POSITIVE', 'score': 0.9997058510780334}
# Score: 5
# Text: This is a wonderful APP, I have all my important information stored in it, This wonderful app saves my important documents, I'm able to retrieve them whenever I lose my phone, THANK YOU! for making this app..." Dropbox!"
# Result: {'label': 'POSITIVE', 'score': 0.999806821346283}
# Score: 5
# Text: Cool and easy app to use.
# Result: {'label': 'POSITIVE', 'score': 0.9998388290405273}
# Score: 5
# Text: synch is frozen for few hours in notification area, unable to cancel job / clear notification. all files are sync, but notification is still flashing. VERY annoying.
# Result: {'label': 'NEGATIVE', 'score': 0.9966741800308228}
# Score: 2
# Text: This is very good
# Result: {'label': 'POSITIVE', 'score': 0.999843955039978}
# Score: 5
# Text: Ultra-useful. No chopiness or lag. UI could use a touch up.
# Result: {'label': 'POSITIVE', 'score': 0.9947062134742737}
# Score: 4
# Text: It's usable
# Result: {'label': 'POSITIVE', 'score': 0.9997082352638245}
# Score: 4
# Text: web based platform is full of bugs
# Result: {'label': 'NEGATIVE', 'score': 0.9990180730819702}
# Score: 1
# Text: I've been using Dropbox for years, the plus for about 5 now. it's great for storing, organizing, and sharing photos and documents. Can't see a reason that I'd ever stop using it
# Result: {'label': 'POSITIVE', 'score': 0.9980366826057434}
# Score: 5
# Text: Excellant
# Result: {'label': 'POSITIVE', 'score': 0.9997606873512268}
# Score: 5
# Text: I'm trying to change my payment method and is not possible
# Result: {'label': 'NEGATIVE', 'score': 0.99980229139328}
# Score: 2
# Text: Dropbox is the best app store ever
# Result: {'label': 'POSITIVE', 'score': 0.9998015761375427}
# Score: 5
# Text: Maksood Ahmad Nice AAP
# Result: {'label': 'POSITIVE', 'score': 0.7375903725624084}
# Score: 5
# Text: Excellent
# Result: {'label': 'POSITIVE', 'score': 0.9998434782028198}
# Score: 5
# Text: nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 5
# Text: It's ate my money with no use of it
# Result: {'label': 'NEGATIVE', 'score': 0.991381824016571}
# Score: 1
# Text: Can't open PDF files - its permission only allows MEDIA files :( - When moving or copying the path resets to root every time :( - Music player with playlists etc. is completely missing - no proper way to play your music collection.
# Result: {'label': 'NEGATIVE', 'score': 0.9997292160987854}
# Score: 3
# Text: I have now used this app for a number of years, it's easy to use and another great product from Google... Thank you very much!!!
# Result: {'label': 'POSITIVE', 'score': 0.9998069405555725}
# Score: 5
# Text: Useful
# Result: {'label': 'POSITIVE', 'score': 0.9997634291648865}
# Score: 5
# Text: I Love it and even more when other users aren't all up in it. 😂
# Result: {'label': 'POSITIVE', 'score': 0.999824583530426}
# Score: 4
# Text: Good app
# Result: {'label': 'POSITIVE', 'score': 0.9998493194580078}
# Score: 5
# Text: best
# Result: {'label': 'POSITIVE', 'score': 0.9997941851615906}
# Score: 5
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: The ONLINE & OFFLINE storage and transferring service has a monthly or annual service charge to use the full benefits HOWEVER the Free limited access is still Exceptional and worth use!
# Result: {'label': 'POSITIVE', 'score': 0.9997461438179016}
# Score: 5
# Text: Cleans Out bad
# Result: {'label': 'NEGATIVE', 'score': 0.9965564012527466}
# Score: 5
# Text: Can't sign in App just not respond Terrible
# Result: {'label': 'NEGATIVE', 'score': 0.9952723383903503}
# Score: 1
# Text: Love this app had it before but lost everything when email was blocked and lost my phone so new number and cant get my old dropbox back all my memories lost
# Result: {'label': 'NEGATIVE', 'score': 0.9993476271629333}
# Score: 4
# Text: Too much money
# Result: {'label': 'NEGATIVE', 'score': 0.999384880065918}
# Score: 1
# Text: I Love this app. thank you
# Result: {'label': 'POSITIVE', 'score': 0.9998719692230225}
# Score: 5
# Text: Crashes every time I try to open a Word document. Absolute garbage.
# Result: {'label': 'NEGATIVE', 'score': 0.9997733235359192}
# Score: 1
# Text: All okay
# Result: {'label': 'POSITIVE', 'score': 0.9998326301574707}
# Score: 5
# Text: Great file sharing program!
# Result: {'label': 'POSITIVE', 'score': 0.9998691082000732}
# Score: 5
# Text: Nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 5
# Text: Issue with editing documents resolved. Happy again.
# Result: {'label': 'POSITIVE', 'score': 0.9998310804367065}
# Score: 5
# Text: Reviews are getting worse each day. I will reinstall when I hear of some improvement and some reflection of this in reviews. The reviews don't lie! The people have spoken.
# Result: {'label': 'NEGATIVE', 'score': 0.9010146856307983}
# Score: 3
# Text: Frequent downloading and uploading errors. Uploading ia nearly impossible even if you a have good internet connection.
# Result: {'label': 'NEGATIVE', 'score': 0.9990527033805847}
# Score: 1
# Text: Dropbox is convenient at times but you have to upgrade to get the full potential.
# Result: {'label': 'NEGATIVE', 'score': 0.9914387464523315}
# Score: 3
# Text: I have been using Dropbox for years and i sign up for Dropbox plus to get access to all my pics from my digital camera. Now I have been charged and none of those pics are no longer in my Dropbox account. I want a refund!! Not happy 😡
# Result: {'label': 'NEGATIVE', 'score': 0.9995449185371399}
# Score: 1
# Text: this not what I wanted. please cancel my subscription
# Result: {'label': 'NEGATIVE', 'score': 0.9997822642326355}
# Score: 1
# Text: super duper
# Result: {'label': 'NEGATIVE', 'score': 0.9975153207778931}
# Score: 5
# Text: Been with me since I got it. Really like it.
# Result: {'label': 'POSITIVE', 'score': 0.9998408555984497}
# Score: 5
# Text: Very useful
# Result: {'label': 'POSITIVE', 'score': 0.999798595905304}
# Score: 5
# Text: I love this App,lets me stay secretive from the woman
# Result: {'label': 'POSITIVE', 'score': 0.9997257590293884}
# Score: 5
# Text: BEST APP EVER!!!
# Result: {'label': 'POSITIVE', 'score': 0.999769389629364}
# Score: 5
# Text: Idiot app. Never and ever use it. It will collect your bank info from google and start debiting min 1.5usd every week, don't know sometimes 2 time a week. I had lost more almost 100usd within 2 months. Still you wanna use it, it's your fate. For me, until I didn't arrived a solution other than blocking all my bank accounts. Cheers for next user.
# Result: {'label': 'NEGATIVE', 'score': 0.9955582618713379}
# Score: 1
# Text: love it
# Result: {'label': 'POSITIVE', 'score': 0.9998753070831299}
# Score: 5
# Text: Can't even excess it at all forcing to pay subscription.
# Result: {'label': 'NEGATIVE', 'score': 0.9913296699523926}
# Score: 1
# Text: good in music
# Result: {'label': 'POSITIVE', 'score': 0.9998492002487183}
# Score: 5
# Text: I really trusts dropbox a lot
# Result: {'label': 'POSITIVE', 'score': 0.999646782875061}
# Score: 5
# Text: Helpful
# Result: {'label': 'POSITIVE', 'score': 0.9997673630714417}
# Score: 5
# Text: Reliable
# Result: {'label': 'POSITIVE', 'score': 0.999845027923584}
# Score: 5
# Text: I want a free version
# Result: {'label': 'NEGATIVE', 'score': 0.9952924251556396}
# Score: 1
# Text: easy to use
# Result: {'label': 'POSITIVE', 'score': 0.9988542795181274}
# Score: 5
# Text: Been a great app and using since 2008
# Result: {'label': 'POSITIVE', 'score': 0.9997615218162537}
# Score: 5
# Text: Wonderful app good for pictures and things you want to keep
# Result: {'label': 'POSITIVE', 'score': 0.9998780488967896}
# Score: 5
# Text: Pricey and confusing 😔
# Result: {'label': 'NEGATIVE', 'score': 0.9598397612571716}
# Score: 3
# Text: Great
# Result: {'label': 'POSITIVE', 'score': 0.9998630285263062}
# Score: 5
# Text: shriya bag
# Result: {'label': 'POSITIVE', 'score': 0.8297826647758484}
# Score: 5
# Text: Unbelievable! Safely looking after my things.
# Result: {'label': 'POSITIVE', 'score': 0.9995326995849609}
# Score: 5
# Text: I have a suggestion.
# Result: {'label': 'POSITIVE', 'score': 0.9972736239433289}
# Score: 1
# Text: Great for storing memories!
# Result: {'label': 'POSITIVE', 'score': 0.9998421669006348}
# Score: 5
# Text: How can I get rid of the whole "home" environment? I don't care about recent, suggestions etc, it's a cloud, I open it to see my files in my folders!
# Result: {'label': 'NEGATIVE', 'score': 0.9948510527610779}
# Score: 1
# Text: They want money, money, money
# Result: {'label': 'NEGATIVE', 'score': 0.9669243097305298}
# Score: 1
# Text: Works fine on PC or browsers but app sends code to login and instantly says, code failed to work.
# Result: {'label': 'NEGATIVE', 'score': 0.9997572302818298}
# Score: 1
# Text: E-Mail App for Yours truly!
# Result: {'label': 'POSITIVE', 'score': 0.9958341121673584}
# Score: 1
# Text: Ssewing
# Result: {'label': 'NEGATIVE', 'score': 0.9963648915290833}
# Score: 1
# Text: pretty good
# Result: {'label': 'POSITIVE', 'score': 0.9998512268066406}
# Score: 5
# Text: Very 👍
# Result: {'label': 'POSITIVE', 'score': 0.8243645429611206}
# Score: 5
# Text: Was great untill yesterday Now just keeps saying permanent failure 😡😡😡😡 And won't up load video or gifs
# Result: {'label': 'NEGATIVE', 'score': 0.9947302341461182}
# Score: 5
# Text: Super convenient, very secure backup and cloud folders for important, and not so, information
# Result: {'label': 'POSITIVE', 'score': 0.9761376976966858}
# Score: 5
# Text: easy to use
# Result: {'label': 'POSITIVE', 'score': 0.9988542795181274}
# Score: 5
# Text: Good more my thik
# Result: {'label': 'POSITIVE', 'score': 0.999786913394928}
# Score: 5
# Text: "Yes, This Application Has Device Mirroring!.!!..!!!..." "Also This Application Does Also Have Calendar Support" "@nd Also Allows Offline Access To All Your Saved Backed Up And Downloaded Files!!!.!!!..!!!...!!!....!!!"
# Result: {'label': 'NEGATIVE', 'score': 0.8801869750022888}
# Score: 5
# Text: Makes lives easier - remotely and at your Desktop!
# Result: {'label': 'POSITIVE', 'score': 0.9941971302032471}
# Score: 5
# Text: Ok
# Result: {'label': 'POSITIVE', 'score': 0.9997851252555847}
# Score: 5
# Text: Worst application in the world no respect with customer
# Result: {'label': 'NEGATIVE', 'score': 0.9998045563697815}
# Score: 1
# Text: I'm being charged for a basic account I've unsubscribed and everything and they are still talking my money despite emails!!! this is a common problem and this company needs held responsible...
# Result: {'label': 'NEGATIVE', 'score': 0.9978379607200623}
# Score: 1
# Text: "Open with default app" option does not work correctly. WHEN YOU TAP ON THE FILENAME, IT OPENS IN DROPBOX – NOT THE DEFAULT APP.
# Result: {'label': 'NEGATIVE', 'score': 0.9997591376304626}
# Score: 2
# Text: It never actually used Dropbox, but they wanted me to pay, so I uninstalled the app
# Result: {'label': 'NEGATIVE', 'score': 0.988090991973877}
# Score: 3
# Text: supar
# Result: {'label': 'POSITIVE', 'score': 0.8584704995155334}
# Score: 5
# Text: terrible. inconvenient. not easy to use. made my afternoon a complete disaster. would not recommend.
# Result: {'label': 'NEGATIVE', 'score': 0.9997517466545105}
# Score: 1
# Text: Downloads will fail randomly for no reason whatsoever. Videos saved to your device will become corrupted. Downloading/uploading is extremely slow. Everything this app is supposed to do, it does poorly. 2 years later update - all of the issues are still there. Support did absolutely nothing to help. I am so happy I cancelled my plan. Please guys, use "Mega" they have actual encryption. Dropbox is a joke.
# Result: {'label': 'NEGATIVE', 'score': 0.9997838139533997}
# Score: 1
# Text: Good Apps
# Result: {'label': 'POSITIVE', 'score': 0.9998608827590942}
# Score: 5
# Text: good keeper
# Result: {'label': 'POSITIVE', 'score': 0.9998519420623779}
# Score: 5
# Text: Human rights is important or not?
# Result: {'label': 'NEGATIVE', 'score': 0.9774042367935181}
# Score: 5
# Text: It's gone so far downhill. A decade ago, I put everything important in Dropbox. 5 years ago, I swapped to putting new important things in Google Drive but keeping Dropbox as a backup. After growing more and more frustrated with Dropbox pop-ups and slowness anytime I wanted to find one file, I'm ripping off the band-aid and moving everything over. I don't want to upgrade. I don't want your AI tool. I don't want any pop-ups, ever. Stop harassing me.
# Result: {'label': 'NEGATIVE', 'score': 0.9991968274116516}
# Score: 1
# Text: Dropbox is nice and good
# Result: {'label': 'POSITIVE', 'score': 0.9998759031295776}
# Score: 5
# Text: Thank you
# Result: {'label': 'POSITIVE', 'score': 0.9998352527618408}
# Score: 5
# Text: Pov:you only have dropbox for dc2 models
# Result: {'label': 'NEGATIVE', 'score': 0.9878712892532349}
# Score: 3
# Text: I shouldn't have to pay for an account to view files that someone else shares with me. Deleting your app. AGAIN.
# Result: {'label': 'NEGATIVE', 'score': 0.9993252754211426}
# Score: 1
# Text: please help me 😭😭😭😭 i lost my lovely memories of my love 😭😭😭
# Result: {'label': 'NEGATIVE', 'score': 0.9734345078468323}
# Score: 1
# Text: No longer needed
# Result: {'label': 'NEGATIVE', 'score': 0.9843988418579102}
# Score: 1
# Text: when playing a video it shows other ones along with the one you are viewing.
# Result: {'label': 'NEGATIVE', 'score': 0.9558268785476685}
# Score: 1
# Text: excellent for moving files across multiple platforms. also pretty decent storage although I believe it's a bit pricey for 2TB, but I paid it anyway so what does that say 🤣
# Result: {'label': 'POSITIVE', 'score': 0.9780852794647217}
# Score: 5
# Text: I'm not sure what to think about this app
# Result: {'label': 'NEGATIVE', 'score': 0.9986478686332703}
# Score: 5
# Text: bahut hi achha app h
# Result: {'label': 'NEGATIVE', 'score': 0.9105814695358276}
# Score: 5
# Text: Needs more connectivity
# Result: {'label': 'NEGATIVE', 'score': 0.9990529417991638}
# Score: 3
# Text: A great app/tool 2 have at ur disposal. Gotta have it.
# Result: {'label': 'POSITIVE', 'score': 0.93267422914505}
# Score: 4
# Text: this is good!
# Result: {'label': 'POSITIVE', 'score': 0.9998394250869751}
# Score: 4
# Text: Dropbox starts out being useful but after a while claims u are out of space and have to buy more space. Even when you delete everything it still claims you are out of space. I am switching to google drive. But, I am sure you are aware of this complaint.
# Result: {'label': 'NEGATIVE', 'score': 0.9991694688796997}
# Score: 1
# Text: very usefull for research students
# Result: {'label': 'POSITIVE', 'score': 0.9989770650863647}
# Score: 5
# Text: dark patterns, expensive..
# Result: {'label': 'NEGATIVE', 'score': 0.9419335722923279}
# Score: 2
# Text: sharan . I
# Result: {'label': 'POSITIVE', 'score': 0.9919896721839905}
# Score: 5
# Text: What i like most is to be able to use Dropbox natively on linux (Ubuntu) as well as on windows and android.but please consider making a good ui for ubuntu and in general linux.thank you.
# Result: {'label': 'POSITIVE', 'score': 0.9993789196014404}
# Score: 5
# Text: Dropbox is a very useful, very helpful tool.
# Result: {'label': 'POSITIVE', 'score': 0.9993570446968079}
# Score: 4
# Text: great for keeping your files well organized in one place.
# Result: {'label': 'POSITIVE', 'score': 0.9997956156730652}
# Score: 5
# Text: very very good 👍😊
# Result: {'label': 'POSITIVE', 'score': 0.9998741149902344}
# Score: 5
# Text: This destination storage thank you
# Result: {'label': 'POSITIVE', 'score': 0.9998058676719666}
# Score: 5
# Text: Fine for years until recently. All of a sudden they say I need to pay for bigger system when I only have 790 kb worth of files (no pix, no videos, no music). In addition, now files will no longer save to Dropbox.
# Result: {'label': 'NEGATIVE', 'score': 0.9992662072181702}
# Score: 3
# Text: Can't find the delete subscription option
# Result: {'label': 'NEGATIVE', 'score': 0.9989222288131714}
# Score: 1
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 4
# Text: Trying to cancel subscription is impossible....
# Result: {'label': 'NEGATIVE', 'score': 0.9991372227668762}
# Score: 1

# %%
df['sentiment'] = [r['label'] for r in results]

# %%
df
# Out:
#                                   reviewId  \
# 2809  97122f45-ef2e-4002-8e08-2c4e5b4c18f8
# 341   9fb5b5bd-0038-44c4-b7b6-7f01adc7dfef
# 3417  68c729df-69a7-408c-87c2-a21a17f7225e
# 1140  841383d4-410e-4be1-abb0-02693d0fe1df
# 7466  8d16fc7f-44d3-4ba2-add5-ffa76ff51949
# ...                                    ...
# 4899  6cc45a6d-799b-4742-b9f5-a7aad8cc92bb
# 6559  892e89c6-6e33-46e2-9669-69547dbe9b1c
# 6510  6e0d595a-c846-4dc1-8b6d-a08fa346788e
# 2238  f5d9e2a8-8be6-4498-9b42-3717cc3f56ab
# 8365  195e965f-7ac3-4639-acf5-d6dbb3e3e9c8
#
#                                                 content  score sentiment
# 2809  Fraudulent company... beware! Dropbox took mon...      1  NEGATIVE
# 341                          I love drop box. awesome!!      5  POSITIVE
# 3417  Can I please use the app for my pictures. So I...      5  NEGATIVE
# 1140                                        easy to use      5  POSITIVE
# 7466  is good but I don't like because I can't not d...      2  POSITIVE
# ...                                                 ...    ...       ...
# 4899                 This destination storage thank you      5  POSITIVE
# 6559  Fine for years until recently. All of a sudden...      3  NEGATIVE
# 6510          Can't find the delete subscription option      1  NEGATIVE
# 2238                                               good      4  POSITIVE
# 8365    Trying to cancel subscription is impossible....      1  NEGATIVE
#
# [200 rows x 4 columns]
